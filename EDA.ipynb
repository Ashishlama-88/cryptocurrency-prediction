# %%
import math
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
import datetime as dt

import pandas as pd
import numpy as np
# Out:
# /Users/ashishlama/anaconda3/lib/python3.11/site-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
selected_tickers=['USDT-GBP','SOL-GBP','ETH-GBP','AR-GBP']

# %%
start = dt.datetime.now() - dt.timedelta(days= 365 * 3)
end = dt.datetime.now()

# %%
df_store = []

for ticker in selected_tickers:
    df_data = yf.download(ticker, start, end)
    df_data['Symbol'] = ticker# adding the 'Crypto' column
    df_store.append(df_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# combine all dataframes into one dataframe
df_data = pd.concat(df_store)
df_data
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2021-05-03   0.723628   0.719092   0.720760   0.719368   0.719368
# 2021-05-04   0.719199   0.721117   0.721058   0.720037   0.720037
# 2021-05-05   0.720060   0.719111   0.718869   0.718869   0.718869
# 2021-05-06   0.719009   0.719679   0.719116   0.719783   0.719783
# 2021-05-07   0.719695   0.716067   0.719489   0.715015   0.715015
# ...               ...        ...        ...        ...        ...
# 2024-04-28  24.784439  27.593096  23.688143  26.803680  26.803680
# 2024-04-29  26.803680  29.822336  26.773088  28.682219  28.682219
# 2024-04-30  28.682219  29.412952  26.903337  28.732679  28.732679
# 2024-05-01  28.732813  29.079653  24.055687  24.187380  24.187380
# 2024-05-02  22.867096  23.282398  21.743162  23.203403  23.203403
#
#                   Volume    Symbol
# Date
# 2021-05-03   82976530949  USDT-GBP
# 2021-05-04  132858911701  USDT-GBP
# 2021-05-05  139956914802  USDT-GBP
# ...

# %%
Solana= df_data[df_data['Symbol']=='SOL-GBP']
Arweave = df_data[df_data['Symbol']=='AR-GBP']
Ethereum = df_data[df_data['Symbol']=='ETH-GBP']
Tether = df_data[df_data['Symbol']=='USDT-GBP']

# %%
Solana
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-05-03   33.942390   35.387276   32.378151   33.037762   33.037762
# 2021-05-04   33.073486   34.461948   30.457989   30.768356   30.768356
# 2021-05-05   30.701880   33.019234   30.461321   32.298210   32.298210
# 2021-05-06   32.334499   32.334499   30.666794   31.273355   31.273355
# 2021-05-07   31.307163   32.956863   29.790337   30.851351   30.851351
# ...                ...         ...         ...         ...         ...
# 2024-04-28  111.381546  114.409485  107.326195  113.139984  113.139984
# 2024-04-29  113.139984  115.722237  109.733719  110.200073  110.200073
# 2024-04-30  110.203094  110.912865  106.426613  109.699295  109.699295
# 2024-05-01  109.699806  111.232018   97.335876  101.660690  101.660690
# 2024-05-02  107.398834  107.371910  102.341690  105.313774  105.313774
#
#                 Volume   Symbol
# Date
# 2021-05-03   438162356  SOL-GBP
# 2021-05-04   491792203  SOL-GBP
# ...

# %%
Solana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1096 entries, 2021-05-03 to 2024-05-02
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1096 non-null   float64
#  1   High       1096 non-null   float64
#  2   Low        1096 non-null   float64
#  3   Close      1096 non-null   float64
#  4   Adj Close  1096 non-null   float64
#  5   Volume     1096 non-null   int64
#  6   Symbol     1096 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.5+ KB

# %%
Solana.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1096.000000  1096.000000  1096.000000  1096.000000  1096.000000
# mean     52.912587    55.203035    50.609825    52.951413    52.951413
# std      43.976989    45.777423    41.934000    43.964965    43.964965
# min       8.006495     8.168565     6.745782     8.006386     8.006386
# 25%      18.796615    19.523565    18.073023    18.798635    18.798635
# 50%      30.666095    32.107992    29.614905    30.586817    30.586817
# 75%      78.565250    81.850569    76.047987    78.784294    78.784294
# max     191.718582   192.667282   182.537933   191.831741   191.831741
#
#              Volume
# count  1.096000e+03
# mean   1.317702e+09
# std    1.338967e+09
# min    7.956453e+07
# 25%    3.709707e+08
# 50%    9.672521e+08
# 75%    1.801252e+09
# max    1.238716e+10

# %%
Arweave
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2021-05-03  19.409307  20.347609  19.339388  19.636206  19.636206   11006868
# 2021-05-04  19.638109  19.638109  18.050920  18.067669  18.067669   11282956
# 2021-05-05  18.075857  20.635813  17.772423  19.791983  19.791983   13370017
# 2021-05-06  19.786654  19.786654  18.738939  18.838255  18.838255   10754061
# 2021-05-07  18.840042  19.262129  18.229523  18.229523  18.229523   10115293
# ...               ...        ...        ...        ...        ...        ...
# 2024-04-28  24.784439  27.593096  23.688143  26.803680  26.803680   82018469
# 2024-04-29  26.803680  29.822336  26.773088  28.682219  28.682219  101707821
# 2024-04-30  28.682219  29.412952  26.903337  28.732679  28.732679   95674918
# 2024-05-01  28.732813  29.079653  24.055687  24.187380  24.187380  107656115
# 2024-05-02  22.867096  23.282398  21.743162  23.203403  23.203403  141103616
#
#             Symbol
# Date
# ...

# %%
Arweave.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1096.000000  1096.000000  1096.000000  1096.000000  1096.000000
# mean     14.922061    15.838887    14.094597    14.921753    14.921753
# std      12.468399    13.390926    11.644308    12.458650    12.458650
# min       3.108417     3.127163     3.055471     3.108366     3.108366
# 25%       6.517472     6.759163     6.213747     6.519048     6.519048
# 50%       8.802179     9.271978     8.502802     8.807515     8.807515
# 75%      22.714972    23.952347    21.248572    22.813291    22.813291
# max      63.483418    67.603371    56.218658    63.872669    63.872669
#
#              Volume
# count  1.096000e+03
# mean   3.228786e+07
# std    4.172705e+07
# min    1.828441e+06
# 25%    1.006996e+07
# 50%    2.051899e+07
# 75%    3.833422e+07
# max    5.045440e+08

# %%
Arweave.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1096 entries, 2021-05-03 to 2024-05-02
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1096 non-null   float64
#  1   High       1096 non-null   float64
#  2   Low        1096 non-null   float64
#  3   Close      1096 non-null   float64
#  4   Adj Close  1096 non-null   float64
#  5   Volume     1096 non-null   int64
#  6   Symbol     1096 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.5+ KB

# %%
Ethereum
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021
describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1096.000000  1096.000000  1096.000000  1096.000000  1096.000000
# mean      0.788502     0.788878     0.788437     0.788571     0.788571
# std       0.045101     0.044862     0.045330     0.045054     0.045054
# min       0.703219     0.703295     0.704500     0.703258     0.703258
# 25%       0.748866     0.750983     0.747953     0.748964     0.748964
# 50%       0.792428     0.792829     0.792141     0.792435     0.792435
# 75%       0.818441     0.818166     0.818214     0.818446     0.818446
# max       0.932246     0.938212     0.940155     0.932247     0.932247
#
#              Volume
# count  1.096000e+03
# mean   4.131759e+10
# std    2.310458e+10
# min    8.125715e+09
# 25%    2.515500e+10
# 50%    3.857517e+10
# 75%    5.273102e+10
# max    1.978192e+11

# %%
Tether.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1096 entries, 2021-05-03 to 2024-05-02
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1096 non-null   float64
#  1   High       1096 non-null   float64
#  2   Low        1096 non-null   float64
#  3   Close      1096 non-null   float64
#  4   Adj Close  1096 non-null   float64
#  5   Volume     1096 non-null   int64
#  6   Symbol     1096 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.5+ KB

# %%
company_list = [Tether,Solana,Ethereum,Arweave]

# %%
plt.figure(figsize=(15, 7))
plt.subplots_adjust(top=1.25, bottom=1.2)
palette = iter(sns.husl_palette(len(company_list)))
for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot( color=next(palette))
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {selected_tickers[i - 1]}")
    
plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
ma_day = [100, 200, 300]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Close'].rolling(ma).mean()
# Out:
# /var/folders/hj/wk5tsj8140dcsjfbc67nj8b00000gn/T/ipykernel_35737/2187055583.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company[column_name] = company['Close'].rolling(ma).mean()
# /var/folders/hj/wk5tsj8140dcsjfbc67nj8b00000gn/T/ipykernel_35737/2187055583.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company[column_name] = company['Close'].rolling(ma).mean()
# /var/folders/hj/wk5tsj8140dcsjfbc67nj8b00000gn/T/ipykernel_35737/2187055583.py:8: SettingWithCopyWarning:
# ...

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

Ethereum[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('ETH-GBP')

Tether[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('USTD-GBP')

Solana[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('SOL-GBP')

Arweave[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('AR-GBP')

fig.tight_layout()

# %%
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

Ethereum['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='-', color='#ffdd00', marker='o', mec='r')
axes[0,0].set_title('ETH-GBP')

Solana['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='-', color="#ff0051", marker='o', mec='b')
axes[0,1].set_title('SOL-GBP')

Tether['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='-', color="#dc00ff", marker='o', mec='g')
axes[1,0].set_title('USDT-GBP')

Arweave['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='-', color="#00e9ff", marker='o', mec ='m')
axes[1,1].set_title('AR-GBP')

fig.tight_layout()
# Out:
# /var/folders/hj/wk5tsj8140dcsjfbc67nj8b00000gn/T/ipykernel_35737/3899831843.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company['Daily Return'] = company['Close'].pct_change()
# /var/folders/hj/wk5tsj8140dcsjfbc67nj8b00000gn/T/ipykernel_35737/3899831843.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company['Daily Return'] = company['Close'].pct_change()
# /var/folders/hj/wk5tsj8140dcsjfbc67nj8b00000gn/T/ipykernel_35737/3899831843.py:3: SettingWithCopyWarning:
# ...

# %%
# Note the use of dropna() here, otherwise the NaN values can't be read by seaborn
plt.figure(figsize=(12, 7))
palette = iter(sns.husl_palette(len(company_list)))
for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    sns.histplot(company['Daily Return'].dropna(), kde=True, stat="density", linewidth=0,
bins=100, color=next(palette))
    plt.ylabel('Daily Return')
    plt.title(f'{selected_tickers[i - 1]}')
plt.tight_layout()

# %% [markdown]
# ### Correlation between different stocks closing prices

# %%
closing_df = yf.download(selected_tickers,start,end)['Close']
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
closing_df
# Out:
# Ticker         AR-GBP      ETH-GBP     SOL-GBP  USDT-GBP
# Date
# 2021-05-03  19.636206  2467.805176   33.037762  0.719368
# 2021-05-04  18.067669  2342.847412   30.768356  0.720037
# 2021-05-05  19.791983  2532.736572   32.298210  0.718869
# 2021-05-06  18.838255  2512.250488   31.273355  0.719783
# 2021-05-07  18.229523  2491.218750   30.851351  0.715015
# ...               ...          ...         ...       ...
# 2024-04-28  26.803680  2604.235352  113.139984  0.800284
# 2024-04-29  28.682219  2608.206543  110.200073  0.799169
# 2024-04-30  28.732679  2560.159912  109.699295  0.795982
# 2024-05-01  24.187380  2411.977051  101.660690  0.800042
# 2024-05-02  23.174900  2330.571533  105.311623  0.796992
#
# [1096 rows x 4 columns]

# %%
# Make a new tech returns DataFrame
crypto_rets = closing_df.pct_change()
crypto_rets.head()
# Out:
# Ticker        AR-GBP   ETH-GBP   SOL-GBP  USDT-GBP
# Date
# 2021-05-03       NaN       NaN       NaN       NaN
# 2021-05-04 -0.079880 -0.050635 -0.068691  0.000930
# 2021-05-05  0.095436  0.081051  0.049722 -0.001622
# 2021-05-06 -0.048188 -0.008089 -0.031731  0.001271
# 2021-05-07 -0.032314 -0.008372 -0.013494 -0.006624

# %%
# Comparing Ethereum to itself should show a perfectly linear relationship
sns.jointplot(data=crypto_rets, kind='scatter',x='AR-GBP', y='AR-GBP', color='seagreen',dropna=True)

# %%
sns.jointplot(data=crypto_rets, kind='scatter',x='AR-GBP', y='SOL-GBP',dropna=True)

# %%
sns.pairplot(crypto_rets) #kind='reg')
# Out:
# /Users/ashishlama/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Let's go ahead and use sebron for a quick correlation plot for the daily returns
sns.heatmap(crypto_rets.corr(), annot=True, cmap='afmhot')
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>

# %%
sns.heatmap(closing_df.corr(), annot=True, cmap='binary')
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>

# %%
# Let's start by defining a new DataFrame as a clenaed version of the oriignal tech_rets DataFrame
rets = crypto_rets.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 7))
plt.scatter(rets.mean(), rets.std(), s=area, color='r')
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='k', connectionstyle='arc3,rad=-0.3'))

# %%
# Out:
# /Users/ashishlama/anaconda3/lib/python3.11/site-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()
